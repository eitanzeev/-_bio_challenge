# %%
import numpy as np
import pandas as pd
import pickle
import json
from modelling_utilities import post_process_epoch_metrics

# %%
def detailed_reportout(metrics):
    
    collect_fold_values = {}
    avg_score_per_metric = {}
    avg_score_per_fold = {}
    max_score_per_metric = {}
    max_score_per_fold = {}
    min_score_per_fold = {}
    min_score_per_metric = {}
    
    
    for data_slice, metrics_and_folds in metrics.items():
       
        collect_fold_values.setdefault(data_slice, {})
        avg_score_per_fold.setdefault(data_slice, {})
        max_score_per_fold.setdefault(data_slice, {})
        min_score_per_fold.setdefault(data_slice, {})

        for metric, fold_report in metrics_and_folds.items():
            
            avg_score_per_fold[data_slice][metric] = {}
            max_score_per_fold[data_slice][metric] = {}
            min_score_per_fold[data_slice][metric] = {}

            for fold_name, fold_values in fold_report.items():
                
                if fold_values:
                    avg_score_per_fold[data_slice][metric].setdefault(fold_name, 0)
                    avg_score_per_fold[data_slice][metric][fold_name] = np.round(np.mean(fold_values), 4)
                    max_score_per_fold[data_slice][metric][fold_name] = np.round(np.max(fold_values),  4)
                    min_score_per_fold[data_slice][metric][fold_name] = np.round(np.min(fold_values), 4)

                    collect_fold_values[data_slice].setdefault(metric, []).extend(fold_values)

            #averaged_across_epochs.setdefault(metric, {})[data_slice] = {fold: np.mean(scores) for fold, scores in enumerate(folds)}

        avg_score_per_metric[data_slice] = {metric: np.round(np.mean(scores), 4) for metric, scores in collect_fold_values[data_slice].items()}

        max_score_per_metric[data_slice] = {metric: np.round(np.max(scores), 4) for metric, scores in collect_fold_values[data_slice].items()}

        min_score_per_metric[data_slice] = {metric: np.round(np.min(scores),4) for metric, scores in collect_fold_values[data_slice].items()}

        
    output_dict = {'avg_score_per_fold': avg_score_per_fold,
                    'avg_score_per_metric':avg_score_per_metric,
                    'max_score_per_metric':max_score_per_metric,
                    'max_score_per_fold':max_score_per_fold, 
                    'min_score_per_fold':min_score_per_fold, 
                    'min_score_per_metric':min_score_per_metric}

    return output_dict

# %%
def performance_summary(results_path):
    with open(results_path, "rb") as f:
        results = pickle.load(f)

    output_dict = detailed_reportout(results)

    for k,v in output_dict.items():
        
        print('Collection Type: ' + k)
        for dataslice, metrics_collect in v.items():

            print("Dataslice: ", dataslice)
            for metric_name, values in metrics_collect.items():
                print(f"Metric Summary Type: {metric_name} -- {values}")
            print('_____________________________________')

# %% [markdown]
# ****

# %% [markdown]
# ## CNN Experiments

# %% [markdown]
# Experiment 1) One Hot Encoding w no AA w no DropOut

# %%
performance_summary("model_results/ProteinCNN_One_Hot_Encoding_No_AA_No_DropOut_model_Training_Slice_exclude_all_q_values_StandardScaler_one_hot.pkl")
# Out:
# Collection Type: avg_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_one_hot
# Metric Summary Type: train_loss -- {'0_fold': 0.2166, '1_fold': 0.2382, '2_fold': 0.2229, '3_fold': 0.2245}
# Metric Summary Type: val_loss -- {'0_fold': 0.2324, '1_fold': 0.2424, '2_fold': 0.2365, '3_fold': 0.2266}
# Metric Summary Type: train_r2 -- {'0_fold': 0.5699, '1_fold': 0.5251, '2_fold': 0.5577, '3_fold': 0.5547}
# Metric Summary Type: val_r2 -- {'0_fold': 0.5372, '1_fold': 0.5236, '2_fold': 0.5285, '3_fold': 0.5472}
# Metric Summary Type: train_mae -- {'0_fold': 0.3617, '1_fold': 0.3824, '2_fold': 0.3682, '3_fold': 0.3676}
# Metric Summary Type: val_mae -- {'0_fold': 0.378, '1_fold': 0.3893, '2_fold': 0.3825, '3_fold': 0.3753}
# Metric Summary Type: train_rmse -- {'0_fold': 0.4492, '1_fold': 0.4707, '2_fold': 0.4547, '3_fold': 0.456}
# Metric Summary Type: val_rmse -- {'0_fold': 0.4712, '1_fold': 0.4797, '2_fold': 0.4737, '3_fold': 0.4641}
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_one_hot
# Metric Summary Type: train_loss -- {'0_fold': 0.2353, '1_fold': 0.2282, '2_fold': 0.2303, '3_fold': 0.2098}
# Metric Summary Type: val_loss -- {'0_fold': 0.2445, '1_fold': 0.2271, '2_fold': 0.2429, '3_fold': 0.2089}
# Metric Summary Type: train_r2 -- {'0_fold': 0.5329, '1_fold': 0.5449, '2_fold': 0.543, '3_fold': 0.5839}
# Metric Summary Type: val_r2 -- {'0_fold': 0.5132, '1_fold': 0.5537, '2_fold': 0.5157, '3_fold': 0.5825}
# Metric Summary Type: train_mae -- {'0_fold': 0.3803, '1_fold': 0.3723, '2_fold': 0.374, '3_fold': 0.3539}
# Metric Summary Type: val_mae -- {'0_fold': 0.3915, '1_fold': 0.3738, '2_fold': 0.3858, '3_fold': 0.3561}
# Metric Summary Type: train_rmse -- {'0_fold': 0.4684, '1_fold': 0.4599, '2_fold': 0.4605, '3_fold': 0.4414}
# Metric Summary Type: val_rmse -- {'0_fold': 0.4828, '1_fold': 0.4631, '2_fold': 0.4794, '3_fold': 0.4441}
# _____________________________________
# Collection Type: avg_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_one_hot
# Metric Summary Type: train_loss -- 0.2256
# Metric Summary Type: val_loss -- 0.2345
# Metric Summary Type: train_r2 -- 0.5518
# Metric Summary Type: val_r2 -- 0.5341
# Metric Summary Type: train_mae -- 0.3700000047683716
# Metric Summary Type: val_mae -- 0.3813000023365021
# Metric Summary Type: train_rmse -- 0.4575999975204468
# Metric Summary Type: val_rmse -- 0.4722000062465668
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_one_hot
# Metric Summary Type: train_loss -- 0.2259
# Metric Summary Type: val_loss -- 0.2309
# Metric Summary Type: train_r2 -- 0.5512
# Metric Summary Type: val_r2 -- 0.5413
# Metric Summary Type: train_mae -- 0.3700999915599823
# Metric Summary Type: val_mae -- 0.376800000667572
# Metric Summary Type: train_rmse -- 0.4575999975204468
# Metric Summary Type: val_rmse -- 0.4674000144004822
# _____________________________________
# Collection Type: max_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_one_hot
# Metric Summary Type: train_loss -- 0.6341
# Metric Summary Type: val_loss -- 0.5598
# Metric Summary Type: train_r2 -- 0.794
# Metric Summary Type: val_r2 -- 0.76
# Metric Summary Type: train_mae -- 0.6740000247955322
# Metric Summary Type: val_mae -- 0.6292999982833862
# Metric Summary Type: train_rmse -- 0.7962999939918518
# Metric Summary Type: val_rmse -- 0.748199999332428
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_one_hot
# Metric Summary Type: train_loss -- 0.64
# Metric Summary Type: val_loss -- 0.5508
# Metric Summary Type: train_r2 -- 0.7998
# Metric Summary Type: val_r2 -- 0.7646
# Metric Summary Type: train_mae -- 0.6747000217437744
# Metric Summary Type: val_mae -- 0.6498000025749207
# Metric Summary Type: train_rmse -- 0.800000011920929
# Metric Summary Type: val_rmse -- 0.7422000169754028
# _____________________________________
# Collection Type: max_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_one_hot
# Metric Summary Type: train_loss -- {'0_fold': 0.579, '1_fold': 0.6058, '2_fold': 0.5911, '3_fold': 0.6341}
# Metric Summary Type: val_loss -- {'0_fold': 0.4994, '1_fold': 0.5055, '2_fold': 0.5598, '3_fold': 0.5165}
# Metric Summary Type: train_r2 -- {'0_fold': 0.7897, '1_fold': 0.7793, '2_fold': 0.7872, '3_fold': 0.794}
# Metric Summary Type: val_r2 -- {'0_fold': 0.7526, '1_fold': 0.7561, '2_fold': 0.7431, '3_fold': 0.76}
# Metric Summary Type: train_mae -- {'0_fold': 0.6527, '1_fold': 0.6679, '2_fold': 0.6583, '3_fold': 0.674}
# Metric Summary Type: val_mae -- {'0_fold': 0.6093, '1_fold': 0.6293, '2_fold': 0.6275, '3_fold': 0.6217}
# Metric Summary Type: train_rmse -- {'0_fold': 0.7609, '1_fold': 0.7783, '2_fold': 0.7689, '3_fold': 0.7963}
# Metric Summary Type: val_rmse -- {'0_fold': 0.7067, '1_fold': 0.711, '2_fold': 0.7482, '3_fold': 0.7187}
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_one_hot
# Metric Summary Type: train_loss -- {'0_fold': 0.6243, '1_fold': 0.6355, '2_fold': 0.64, '3_fold': 0.5772}
# Metric Summary Type: val_loss -- {'0_fold': 0.4977, '1_fold': 0.5206, '2_fold': 0.5508, '3_fold': 0.5411}
# Metric Summary Type: train_r2 -- {'0_fold': 0.7756, '1_fold': 0.7805, '2_fold': 0.7998, '3_fold': 0.7828}
# Metric Summary Type: val_r2 -- {'0_fold': 0.7439, '1_fold': 0.7579, '2_fold': 0.7388, '3_fold': 0.7646}
# Metric Summary Type: train_mae -- {'0_fold': 0.6704, '1_fold': 0.6711, '2_fold': 0.6747, '3_fold': 0.6505}
# Metric Summary Type: val_mae -- {'0_fold': 0.6261, '1_fold': 0.646, '2_fold': 0.6498, '3_fold': 0.6112}
# Metric Summary Type: train_rmse -- {'0_fold': 0.7901, '1_fold': 0.7972, '2_fold': 0.8, '3_fold': 0.7597}
# Metric Summary Type: val_rmse -- {'0_fold': 0.7055, '1_fold': 0.7215, '2_fold': 0.7422, '3_fold': 0.7356}
# _____________________________________
# Collection Type: min_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_one_hot
# Metric Summary Type: train_loss -- {'0_fold': 0.1059, '1_fold': 0.1107, '2_fold': 0.1073, '3_fold': 0.1039}
# Metric Summary Type: val_loss -- {'0_fold': 0.1243, '1_fold': 0.1241, '2_fold': 0.1288, '3_fold': 0.1201}
# Metric Summary Type: train_r2 -- {'0_fold': -0.1495, '1_fold': -0.208, '2_fold': -0.173, '3_fold': -0.2577}
# Metric Summary Type: val_r2 -- {'0_fold': 0.0057, '1_fold': 0.0065, '2_fold': -0.1163, '3_fold': -0.032}
# Metric Summary Type: train_mae -- {'0_fold': 0.2495, '1_fold': 0.2565, '2_fold': 0.2539, '3_fold': 0.247}
# Metric Summary Type: val_mae -- {'0_fold': 0.2718, '1_fold': 0.2685, '2_fold': 0.2694, '3_fold': 0.261}
# Metric Summary Type: train_rmse -- {'0_fold': 0.3254, '1_fold': 0.3327, '2_fold': 0.3275, '3_fold': 0.3223}
# Metric Summary Type: val_rmse -- {'0_fold': 0.3525, '1_fold': 0.3523, '2_fold': 0.359, '3_fold': 0.3466}
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_one_hot
# Metric Summary Type: train_loss -- {'0_fold': 0.113, '1_fold': 0.1101, '2_fold': 0.1009, '3_fold': 0.1095}
# Metric Summary Type: val_loss -- {'0_fold': 0.1286, '1_fold': 0.1232, '2_fold': 0.131, '3_fold': 0.1178}
# Metric Summary Type: train_r2 -- {'0_fold': -0.2396, '1_fold': -0.2672, '2_fold': -0.2699, '3_fold': -0.1448}
# Metric Summary Type: val_r2 -- {'0_fold': 0.0091, '1_fold': -0.023, '2_fold': -0.0984, '3_fold': -0.0811}
# Metric Summary Type: train_mae -- {'0_fold': 0.2609, '1_fold': 0.2554, '2_fold': 0.2442, '3_fold': 0.2545}
# Metric Summary Type: val_mae -- {'0_fold': 0.2759, '1_fold': 0.2653, '2_fold': 0.2747, '3_fold': 0.2629}
# Metric Summary Type: train_rmse -- {'0_fold': 0.3362, '1_fold': 0.3318, '2_fold': 0.3176, '3_fold': 0.3309}
# Metric Summary Type: val_rmse -- {'0_fold': 0.3587, '1_fold': 0.351, '2_fold': 0.3619, '3_fold': 0.3433}
# _____________________________________
# Collection Type: min_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_one_hot
# Metric Summary Type: train_loss -- 0.1039
# Metric Summary Type: val_loss -- 0.1201
# Metric Summary Type: train_r2 -- -0.2577
# Metric Summary Type: val_r2 -- -0.1163
# Metric Summary Type: train_mae -- 0.24699999392032623
# Metric Summary Type: val_mae -- 0.26100000739097595
# Metric Summary Type: train_rmse -- 0.322299987077713
# Metric Summary Type: val_rmse -- 0.3465999960899353
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_one_hot
# Metric Summary Type: train_loss -- 0.1009
# Metric Summary Type: val_loss -- 0.1178
# Metric Summary Type: train_r2 -- -0.2699
# Metric Summary Type: val_r2 -- -0.0984
# Metric Summary Type: train_mae -- 0.24420000612735748
# Metric Summary Type: val_mae -- 0.2628999948501587
# Metric Summary Type: train_rmse -- 0.3176000118255615
# Metric Summary Type: val_rmse -- 0.3433000147342682
# _____________________________________

# %% [markdown]
# Experiment 2) Embedding w no AA w no DropOut

# %%
performance_summary("./model_results/ProteinCNN_Embedding_No_AA_No_Dropout_model_Training_Slice_exclude_all_q_values_StandardScaler_embeddings.pkl")
# Out:
# Collection Type: avg_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.2344, '1_fold': 0.243, '2_fold': 0.2135, '3_fold': 0.2165}
# Metric Summary Type: val_loss -- {'0_fold': 0.2525, '1_fold': 0.2392, '2_fold': 0.223, '3_fold': 0.2078}
# Metric Summary Type: train_r2 -- {'0_fold': 0.5346, '1_fold': 0.5154, '2_fold': 0.5764, '3_fold': 0.5707}
# Metric Summary Type: val_r2 -- {'0_fold': 0.4972, '1_fold': 0.5298, '2_fold': 0.5554, '3_fold': 0.5848}
# Metric Summary Type: train_mae -- {'0_fold': 0.3784, '1_fold': 0.3793, '2_fold': 0.3529, '3_fold': 0.3571}
# Metric Summary Type: val_mae -- {'0_fold': 0.3987, '1_fold': 0.3883, '2_fold': 0.3646, '3_fold': 0.3588}
# Metric Summary Type: train_rmse -- {'0_fold': 0.4661, '1_fold': 0.4705, '2_fold': 0.442, '3_fold': 0.4481}
# Metric Summary Type: val_rmse -- {'0_fold': 0.4906, '1_fold': 0.4766, '2_fold': 0.4576, '3_fold': 0.4456}
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.2415, '1_fold': 0.2289, '2_fold': 0.21, '3_fold': 0.2624}
# Metric Summary Type: val_loss -- {'0_fold': 0.2377, '1_fold': 0.2324, '2_fold': 0.2228, '3_fold': 0.2345}
# Metric Summary Type: train_r2 -- {'0_fold': 0.5205, '1_fold': 0.5436, '2_fold': 0.5832, '3_fold': 0.4796}
# Metric Summary Type: val_r2 -- {'0_fold': 0.5268, '1_fold': 0.5433, '2_fold': 0.5557, '3_fold': 0.5314}
# Metric Summary Type: train_mae -- {'0_fold': 0.3793, '1_fold': 0.3721, '2_fold': 0.3505, '3_fold': 0.3953}
# Metric Summary Type: val_mae -- {'0_fold': 0.3889, '1_fold': 0.382, '2_fold': 0.3696, '3_fold': 0.3877}
# Metric Summary Type: train_rmse -- {'0_fold': 0.4708, '1_fold': 0.461, '2_fold': 0.4395, '3_fold': 0.4886}
# Metric Summary Type: val_rmse -- {'0_fold': 0.478, '1_fold': 0.4707, '2_fold': 0.4621, '3_fold': 0.474}
# _____________________________________
# Collection Type: avg_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 0.2268
# Metric Summary Type: val_loss -- 0.2306
# Metric Summary Type: train_r2 -- 0.5493
# Metric Summary Type: val_r2 -- 0.5418
# Metric Summary Type: train_mae -- 0.3668999969959259
# Metric Summary Type: val_mae -- 0.3776000142097473
# Metric Summary Type: train_rmse -- 0.45669999718666077
# Metric Summary Type: val_rmse -- 0.4675999879837036
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_embeddings
# Metric Summary Type: train_loss -- 0.2357
# Metric Summary Type: val_loss -- 0.2318
# Metric Summary Type: train_r2 -- 0.5317
# Metric Summary Type: val_r2 -- 0.5393
# Metric Summary Type: train_mae -- 0.3743000030517578
# Metric Summary Type: val_mae -- 0.382099986076355
# Metric Summary Type: train_rmse -- 0.4650000035762787
# Metric Summary Type: val_rmse -- 0.47119998931884766
# _____________________________________
# Collection Type: max_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 0.9216
# Metric Summary Type: val_loss -- 0.6018
# Metric Summary Type: train_r2 -- 0.8091
# Metric Summary Type: val_r2 -- 0.7734
# Metric Summary Type: train_mae -- 0.7472000122070312
# Metric Summary Type: val_mae -- 0.6628000140190125
# Metric Summary Type: train_rmse -- 0.9599999785423279
# Metric Summary Type: val_rmse -- 0.7757999897003174
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_embeddings
# Metric Summary Type: train_loss -- 1.1612
# Metric Summary Type: val_loss -- 0.5712
# Metric Summary Type: train_r2 -- 0.7991
# Metric Summary Type: val_r2 -- 0.765
# Metric Summary Type: train_mae -- 0.802299976348877
# Metric Summary Type: val_mae -- 0.6281999945640564
# Metric Summary Type: train_rmse -- 1.0776000022888184
# Metric Summary Type: val_rmse -- 0.7558000087738037
# _____________________________________
# Collection Type: max_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.737, '1_fold': 0.9216, '2_fold': 0.7286, '3_fold': 0.6795}
# Metric Summary Type: val_loss -- {'0_fold': 0.5172, '1_fold': 0.5457, '2_fold': 0.6018, '3_fold': 0.4868}
# Metric Summary Type: train_r2 -- {'0_fold': 0.7852, '1_fold': 0.7908, '2_fold': 0.8091, '3_fold': 0.7869}
# Metric Summary Type: val_r2 -- {'0_fold': 0.7175, '1_fold': 0.7345, '2_fold': 0.7669, '3_fold': 0.7734}
# Metric Summary Type: train_mae -- {'0_fold': 0.7034, '1_fold': 0.7472, '2_fold': 0.6994, '3_fold': 0.6785}
# Metric Summary Type: val_mae -- {'0_fold': 0.6221, '1_fold': 0.6628, '2_fold': 0.6125, '3_fold': 0.6255}
# Metric Summary Type: train_rmse -- {'0_fold': 0.8585, '1_fold': 0.96, '2_fold': 0.8536, '3_fold': 0.8243}
# Metric Summary Type: val_rmse -- {'0_fold': 0.7192, '1_fold': 0.7387, '2_fold': 0.7758, '3_fold': 0.6977}
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.9209, '1_fold': 0.7402, '2_fold': 0.7412, '3_fold': 1.1612}
# Metric Summary Type: val_loss -- {'0_fold': 0.498, '1_fold': 0.4999, '2_fold': 0.5712, '3_fold': 0.4951}
# Metric Summary Type: train_r2 -- {'0_fold': 0.7887, '1_fold': 0.7804, '2_fold': 0.7991, '3_fold': 0.7563}
# Metric Summary Type: val_r2 -- {'0_fold': 0.7325, '1_fold': 0.7581, '2_fold': 0.765, '3_fold': 0.7448}
# Metric Summary Type: train_mae -- {'0_fold': 0.7528, '1_fold': 0.7054, '2_fold': 0.7041, '3_fold': 0.8023}
# Metric Summary Type: val_mae -- {'0_fold': 0.6151, '1_fold': 0.6132, '2_fold': 0.6075, '3_fold': 0.6282}
# Metric Summary Type: train_rmse -- {'0_fold': 0.9596, '1_fold': 0.8603, '2_fold': 0.8609, '3_fold': 1.0776}
# Metric Summary Type: val_rmse -- {'0_fold': 0.7057, '1_fold': 0.7071, '2_fold': 0.7558, '3_fold': 0.7036}
# _____________________________________
# Collection Type: min_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.1082, '1_fold': 0.1049, '2_fold': 0.0962, '3_fold': 0.1075}
# Metric Summary Type: val_loss -- {'0_fold': 0.1419, '1_fold': 0.1351, '2_fold': 0.1169, '3_fold': 0.1134}
# Metric Summary Type: train_r2 -- {'0_fold': -0.4633, '1_fold': -0.8376, '2_fold': -0.4458, '3_fold': -0.3478}
# Metric Summary Type: val_r2 -- {'0_fold': -0.0298, '1_fold': -0.0724, '2_fold': -0.2001, '3_fold': 0.0273}
# Metric Summary Type: train_mae -- {'0_fold': 0.2569, '1_fold': 0.2501, '2_fold': 0.2398, '3_fold': 0.2517}
# Metric Summary Type: val_mae -- {'0_fold': 0.2922, '1_fold': 0.2826, '2_fold': 0.2571, '3_fold': 0.2602}
# Metric Summary Type: train_rmse -- {'0_fold': 0.3289, '1_fold': 0.3239, '2_fold': 0.3102, '3_fold': 0.3278}
# Metric Summary Type: val_rmse -- {'0_fold': 0.3767, '1_fold': 0.3675, '2_fold': 0.3419, '3_fold': 0.3367}
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.1064, '1_fold': 0.1101, '2_fold': 0.1013, '3_fold': 0.1229}
# Metric Summary Type: val_loss -- {'0_fold': 0.1344, '1_fold': 0.1231, '2_fold': 0.1178, '3_fold': 0.1277}
# Metric Summary Type: train_r2 -- {'0_fold': -0.8285, '1_fold': -0.476, '2_fold': -0.4708, '3_fold': -1.3031}
# Metric Summary Type: val_r2 -- {'0_fold': 0.0086, '1_fold': 0.0175, '2_fold': -0.1391, '3_fold': 0.0108}
# Metric Summary Type: train_mae -- {'0_fold': 0.2539, '1_fold': 0.2561, '2_fold': 0.2433, '3_fold': 0.277}
# Metric Summary Type: val_mae -- {'0_fold': 0.2824, '1_fold': 0.2674, '2_fold': 0.2595, '3_fold': 0.2796}
# Metric Summary Type: train_rmse -- {'0_fold': 0.3262, '1_fold': 0.3319, '2_fold': 0.3182, '3_fold': 0.3505}
# Metric Summary Type: val_rmse -- {'0_fold': 0.3666, '1_fold': 0.3508, '2_fold': 0.3433, '3_fold': 0.3574}
# _____________________________________
# Collection Type: min_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 0.0962
# Metric Summary Type: val_loss -- 0.1134
# Metric Summary Type: train_r2 -- -0.8376
# Metric Summary Type: val_r2 -- -0.2001
# Metric Summary Type: train_mae -- 0.23980000615119934
# Metric Summary Type: val_mae -- 0.257099986076355
# Metric Summary Type: train_rmse -- 0.3102000057697296
# Metric Summary Type: val_rmse -- 0.3366999924182892
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_embeddings
# Metric Summary Type: train_loss -- 0.1013
# Metric Summary Type: val_loss -- 0.1178
# Metric Summary Type: train_r2 -- -1.3031
# Metric Summary Type: val_r2 -- -0.1391
# Metric Summary Type: train_mae -- 0.24330000579357147
# Metric Summary Type: val_mae -- 0.25949999690055847
# Metric Summary Type: train_rmse -- 0.3181999921798706
# Metric Summary Type: val_rmse -- 0.3433000147342682
# _____________________________________

# %% [markdown]
# Experiment 3 - Embedding w AA w no DropOut

# %%
performance_summary("./model_results/ProteinCNN_Embedding_w_AA_No_Dropout_model_Training_Slice_exclude_all_q_values_StandardScaler_embeddings.pkl")
# Out:
# Collection Type: avg_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.2179, '1_fold': 0.2367, '2_fold': 0.2662, '3_fold': 0.2216}
# Metric Summary Type: val_loss -- {'0_fold': 0.2181, '1_fold': 0.2373, '2_fold': 0.276, '3_fold': 0.2355}
# Metric Summary Type: train_r2 -- {'0_fold': 0.5674, '1_fold': 0.5281, '2_fold': 0.4717, '3_fold': 0.5605}
# Metric Summary Type: val_r2 -- {'0_fold': 0.5658, '1_fold': 0.5337, '2_fold': 0.4497, '3_fold': 0.5295}
# Metric Summary Type: train_mae -- {'0_fold': 0.3581, '1_fold': 0.3779, '2_fold': 0.3999, '3_fold': 0.3637}
# Metric Summary Type: val_mae -- {'0_fold': 0.3696, '1_fold': 0.3876, '2_fold': 0.424, '3_fold': 0.3789}
# Metric Summary Type: train_rmse -- {'0_fold': 0.4475, '1_fold': 0.4671, '2_fold': 0.4923, '3_fold': 0.4546}
# Metric Summary Type: val_rmse -- {'0_fold': 0.4569, '1_fold': 0.4767, '2_fold': 0.5169, '3_fold': 0.472}
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.2269, '1_fold': 0.2453, '2_fold': 0.2365, '3_fold': 0.2458}
# Metric Summary Type: val_loss -- {'0_fold': 0.2347, '1_fold': 0.2416, '2_fold': 0.2413, '3_fold': 0.2342}
# Metric Summary Type: train_r2 -- {'0_fold': 0.5495, '1_fold': 0.5108, '2_fold': 0.5306, '3_fold': 0.5126}
# Metric Summary Type: val_r2 -- {'0_fold': 0.5327, '1_fold': 0.5252, '2_fold': 0.5188, '3_fold': 0.532}
# Metric Summary Type: train_mae -- {'0_fold': 0.371, '1_fold': 0.3852, '2_fold': 0.3764, '3_fold': 0.3846}
# Metric Summary Type: val_mae -- {'0_fold': 0.3824, '1_fold': 0.3874, '2_fold': 0.3955, '3_fold': 0.3851}
# Metric Summary Type: train_rmse -- {'0_fold': 0.4584, '1_fold': 0.4755, '2_fold': 0.4657, '3_fold': 0.4762}
# Metric Summary Type: val_rmse -- {'0_fold': 0.4754, '1_fold': 0.4799, '2_fold': 0.4838, '3_fold': 0.4719}
# _____________________________________
# Collection Type: avg_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 0.2356
# Metric Summary Type: val_loss -- 0.2417
# Metric Summary Type: train_r2 -- 0.5319
# Metric Summary Type: val_r2 -- 0.5197
# Metric Summary Type: train_mae -- 0.3749000132083893
# Metric Summary Type: val_mae -- 0.38999998569488525
# Metric Summary Type: train_rmse -- 0.46540001034736633
# Metric Summary Type: val_rmse -- 0.4805999994277954
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_embeddings
# Metric Summary Type: train_loss -- 0.2386
# Metric Summary Type: val_loss -- 0.238
# Metric Summary Type: train_r2 -- 0.5259
# Metric Summary Type: val_r2 -- 0.5272
# Metric Summary Type: train_mae -- 0.37929999828338623
# Metric Summary Type: val_mae -- 0.38760000467300415
# Metric Summary Type: train_rmse -- 0.46889999508857727
# Metric Summary Type: val_rmse -- 0.47780001163482666
# _____________________________________
# Collection Type: max_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 1.1469
# Metric Summary Type: val_loss -- 0.5137
# Metric Summary Type: train_r2 -- 0.7963
# Metric Summary Type: val_r2 -- 0.7784
# Metric Summary Type: train_mae -- 0.8198000192642212
# Metric Summary Type: val_mae -- 0.6425999999046326
# Metric Summary Type: train_rmse -- 1.0709999799728394
# Metric Summary Type: val_rmse -- 0.71670001745224
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_embeddings
# Metric Summary Type: train_loss -- 0.9107
# Metric Summary Type: val_loss -- 0.5921
# Metric Summary Type: train_r2 -- 0.7797
# Metric Summary Type: val_r2 -- 0.7527
# Metric Summary Type: train_mae -- 0.7379999756813049
# Metric Summary Type: val_mae -- 0.6225000023841858
# Metric Summary Type: train_rmse -- 0.9542999863624573
# Metric Summary Type: val_rmse -- 0.7695000171661377
# _____________________________________
# Collection Type: max_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.7552, '1_fold': 0.8704, '2_fold': 1.1469, '3_fold': 0.6714}
# Metric Summary Type: val_loss -- {'0_fold': 0.5137, '1_fold': 0.5063, '2_fold': 0.4978, '3_fold': 0.4865}
# Metric Summary Type: train_r2 -- {'0_fold': 0.7963, '1_fold': 0.7791, '2_fold': 0.7468, '3_fold': 0.789}
# Metric Summary Type: val_r2 -- {'0_fold': 0.7646, '1_fold': 0.7309, '2_fold': 0.7047, '3_fold': 0.7784}
# Metric Summary Type: train_mae -- {'0_fold': 0.7042, '1_fold': 0.74, '2_fold': 0.8198, '3_fold': 0.6806}
# Metric Summary Type: val_mae -- {'0_fold': 0.6426, '1_fold': 0.6133, '2_fold': 0.6277, '3_fold': 0.6133}
# Metric Summary Type: train_rmse -- {'0_fold': 0.869, '1_fold': 0.9329, '2_fold': 1.071, '3_fold': 0.8194}
# Metric Summary Type: val_rmse -- {'0_fold': 0.7167, '1_fold': 0.7116, '2_fold': 0.7056, '3_fold': 0.6975}
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.7722, '1_fold': 0.8975, '2_fold': 0.8946, '3_fold': 0.9107}
# Metric Summary Type: val_loss -- {'0_fold': 0.4672, '1_fold': 0.5921, '2_fold': 0.4885, '3_fold': 0.4694}
# Metric Summary Type: train_r2 -- {'0_fold': 0.7791, '1_fold': 0.7677, '2_fold': 0.7797, '3_fold': 0.7673}
# Metric Summary Type: val_r2 -- {'0_fold': 0.7068, '1_fold': 0.7426, '2_fold': 0.7339, '3_fold': 0.7527}
# Metric Summary Type: train_mae -- {'0_fold': 0.7041, '1_fold': 0.7293, '2_fold': 0.738, '3_fold': 0.7278}
# Metric Summary Type: val_mae -- {'0_fold': 0.5931, '1_fold': 0.6006, '2_fold': 0.6225, '3_fold': 0.6043}
# Metric Summary Type: train_rmse -- {'0_fold': 0.8788, '1_fold': 0.9474, '2_fold': 0.9458, '3_fold': 0.9543}
# Metric Summary Type: val_rmse -- {'0_fold': 0.6835, '1_fold': 0.7695, '2_fold': 0.6989, '3_fold': 0.6851}
# _____________________________________
# Collection Type: min_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.1026, '1_fold': 0.1108, '2_fold': 0.1276, '3_fold': 0.1064}
# Metric Summary Type: val_loss -- {'0_fold': 0.1182, '1_fold': 0.1369, '2_fold': 0.1481, '3_fold': 0.1109}
# Metric Summary Type: train_r2 -- {'0_fold': -0.4994, '1_fold': -0.7356, '2_fold': -1.2759, '3_fold': -0.3315}
# Metric Summary Type: val_r2 -- {'0_fold': -0.0227, '1_fold': 0.0049, '2_fold': 0.0072, '3_fold': 0.0279}
# Metric Summary Type: train_mae -- {'0_fold': 0.245, '1_fold': 0.2618, '2_fold': 0.2828, '3_fold': 0.2512}
# Metric Summary Type: val_mae -- {'0_fold': 0.2647, '1_fold': 0.2839, '2_fold': 0.3048, '3_fold': 0.2545}
# Metric Summary Type: train_rmse -- {'0_fold': 0.3203, '1_fold': 0.3328, '2_fold': 0.3572, '3_fold': 0.3262}
# Metric Summary Type: val_rmse -- {'0_fold': 0.3438, '1_fold': 0.37, '2_fold': 0.3848, '3_fold': 0.333}
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.1112, '1_fold': 0.1165, '2_fold': 0.111, '3_fold': 0.1173}
# Metric Summary Type: val_loss -- {'0_fold': 0.1473, '1_fold': 0.131, '2_fold': 0.1335, '3_fold': 0.1237}
# Metric Summary Type: train_r2 -- {'0_fold': -0.5333, '1_fold': -0.7897, '2_fold': -0.7753, '3_fold': -0.8062}
# Metric Summary Type: val_r2 -- {'0_fold': 0.0698, '1_fold': -0.1636, '2_fold': 0.0258, '3_fold': 0.0621}
# Metric Summary Type: train_mae -- {'0_fold': 0.2617, '1_fold': 0.2689, '2_fold': 0.2628, '3_fold': 0.2704}
# Metric Summary Type: val_mae -- {'0_fold': 0.294, '1_fold': 0.2823, '2_fold': 0.2879, '3_fold': 0.2776}
# Metric Summary Type: train_rmse -- {'0_fold': 0.3335, '1_fold': 0.3413, '2_fold': 0.3332, '3_fold': 0.3425}
# Metric Summary Type: val_rmse -- {'0_fold': 0.3837, '1_fold': 0.3619, '2_fold': 0.3653, '3_fold': 0.3518}
# _____________________________________
# Collection Type: min_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 0.1026
# Metric Summary Type: val_loss -- 0.1109
# Metric Summary Type: train_r2 -- -1.2759
# Metric Summary Type: val_r2 -- -0.0227
# Metric Summary Type: train_mae -- 0.24500000476837158
# Metric Summary Type: val_mae -- 0.25450000166893005
# Metric Summary Type: train_rmse -- 0.32030001282691956
# Metric Summary Type: val_rmse -- 0.3330000042915344
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_embeddings
# Metric Summary Type: train_loss -- 0.111
# Metric Summary Type: val_loss -- 0.1237
# Metric Summary Type: train_r2 -- -0.8062
# Metric Summary Type: val_r2 -- -0.1636
# Metric Summary Type: train_mae -- 0.26170000433921814
# Metric Summary Type: val_mae -- 0.2775999903678894
# Metric Summary Type: train_rmse -- 0.33320000767707825
# Metric Summary Type: val_rmse -- 0.35179999470710754
# _____________________________________

# %% [markdown]
# Experiment 4 - Embedding w AA w DropOut - MinMax

# %%
performance_summary("./model_results/ProteinCNN_Embedding_w_AA_w_Dropout_model_Training_Slice_exclude_all_q_values_StandardScaler_embeddings.pkl")
# Out:
# Collection Type: avg_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.301, '1_fold': 0.3272, '2_fold': 0.2584, '3_fold': 0.2879}
# Metric Summary Type: val_loss -- {'0_fold': 0.2628, '1_fold': 0.2559, '2_fold': 0.2414, '3_fold': 0.2573}
# Metric Summary Type: train_r2 -- {'0_fold': 0.4024, '1_fold': 0.3475, '2_fold': 0.4873, '3_fold': 0.4291}
# Metric Summary Type: val_r2 -- {'0_fold': 0.4768, '1_fold': 0.497, '2_fold': 0.5185, '3_fold': 0.4859}
# Metric Summary Type: train_mae -- {'0_fold': 0.4312, '1_fold': 0.4465, '2_fold': 0.4019, '3_fold': 0.4231}
# Metric Summary Type: val_mae -- {'0_fold': 0.4134, '1_fold': 0.4061, '2_fold': 0.3923, '3_fold': 0.4085}
# Metric Summary Type: train_rmse -- {'0_fold': 0.5318, '1_fold': 0.5525, '2_fold': 0.4955, '3_fold': 0.5215}
# Metric Summary Type: val_rmse -- {'0_fold': 0.5046, '1_fold': 0.4969, '2_fold': 0.4837, '3_fold': 0.4979}
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.2883, '1_fold': 0.2715, '2_fold': 0.2608, '3_fold': 0.3297}
# Metric Summary Type: val_loss -- {'0_fold': 0.261, '1_fold': 0.2422, '2_fold': 0.2473, '3_fold': 0.2568}
# Metric Summary Type: train_r2 -- {'0_fold': 0.4277, '1_fold': 0.4586, '2_fold': 0.4825, '3_fold': 0.3462}
# Metric Summary Type: val_r2 -- {'0_fold': 0.4803, '1_fold': 0.5239, '2_fold': 0.5069, '3_fold': 0.4869}
# Metric Summary Type: train_mae -- {'0_fold': 0.4209, '1_fold': 0.4091, '2_fold': 0.4007, '3_fold': 0.446}
# Metric Summary Type: val_mae -- {'0_fold': 0.4089, '1_fold': 0.3918, '2_fold': 0.3925, '3_fold': 0.4106}
# Metric Summary Type: train_rmse -- {'0_fold': 0.5192, '1_fold': 0.506, '2_fold': 0.4959, '3_fold': 0.5535}
# Metric Summary Type: val_rmse -- {'0_fold': 0.5013, '1_fold': 0.4834, '2_fold': 0.4885, '3_fold': 0.497}
# _____________________________________
# Collection Type: avg_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 0.2936
# Metric Summary Type: val_loss -- 0.2544
# Metric Summary Type: train_r2 -- 0.4166
# Metric Summary Type: val_r2 -- 0.4946
# Metric Summary Type: train_mae -- 0.42570000886917114
# Metric Summary Type: val_mae -- 0.4050999879837036
# Metric Summary Type: train_rmse -- 0.5253000259399414
# Metric Summary Type: val_rmse -- 0.4957999885082245
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_embeddings
# Metric Summary Type: train_loss -- 0.2876
# Metric Summary Type: val_loss -- 0.2518
# Metric Summary Type: train_r2 -- 0.4287
# Metric Summary Type: val_r2 -- 0.4995
# Metric Summary Type: train_mae -- 0.41920000314712524
# Metric Summary Type: val_mae -- 0.4009999930858612
# Metric Summary Type: train_rmse -- 0.5185999870300293
# Metric Summary Type: val_rmse -- 0.4925000071525574
# _____________________________________
# Collection Type: max_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 1.3222
# Metric Summary Type: val_loss -- 0.5831
# Metric Summary Type: train_r2 -- 0.6982
# Metric Summary Type: val_r2 -- 0.7171
# Metric Summary Type: train_mae -- 0.8651999831199646
# Metric Summary Type: val_mae -- 0.6809999942779541
# Metric Summary Type: train_rmse -- 1.149899959564209
# Metric Summary Type: val_rmse -- 0.7635999917984009
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_embeddings
# Metric Summary Type: train_loss -- 1.3512
# Metric Summary Type: val_loss -- 0.5399
# Metric Summary Type: train_r2 -- 0.7109
# Metric Summary Type: val_r2 -- 0.7156
# Metric Summary Type: train_mae -- 0.817799985408783
# Metric Summary Type: val_mae -- 0.6258999705314636
# Metric Summary Type: train_rmse -- 1.1624000072479248
# Metric Summary Type: val_rmse -- 0.7347000241279602
# _____________________________________
# Collection Type: max_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 1.0484, '1_fold': 1.3222, '2_fold': 0.6808, '3_fold': 0.934}
# Metric Summary Type: val_loss -- {'0_fold': 0.5831, '1_fold': 0.5173, '2_fold': 0.4877, '3_fold': 0.534}
# Metric Summary Type: train_r2 -- {'0_fold': 0.6742, '1_fold': 0.6286, '2_fold': 0.6964, '3_fold': 0.6982}
# Metric Summary Type: val_r2 -- {'0_fold': 0.6702, '1_fold': 0.7171, '2_fold': 0.7003, '3_fold': 0.7153}
# Metric Summary Type: train_mae -- {'0_fold': 0.7903, '1_fold': 0.8652, '2_fold': 0.6841, '3_fold': 0.7517}
# Metric Summary Type: val_mae -- {'0_fold': 0.681, '1_fold': 0.6133, '2_fold': 0.6088, '3_fold': 0.6502}
# Metric Summary Type: train_rmse -- {'0_fold': 1.0239, '1_fold': 1.1499, '2_fold': 0.8251, '3_fold': 0.9664}
# Metric Summary Type: val_rmse -- {'0_fold': 0.7636, '1_fold': 0.7192, '2_fold': 0.6983, '3_fold': 0.7308}
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 1.0034, '1_fold': 0.8989, '2_fold': 0.7687, '3_fold': 1.3512}
# Metric Summary Type: val_loss -- {'0_fold': 0.5399, '1_fold': 0.4813, '2_fold': 0.4869, '3_fold': 0.4763}
# Metric Summary Type: train_r2 -- {'0_fold': 0.6971, '1_fold': 0.6983, '2_fold': 0.7109, '3_fold': 0.6612}
# Metric Summary Type: val_r2 -- {'0_fold': 0.7081, '1_fold': 0.7127, '2_fold': 0.7073, '3_fold': 0.7156}
# Metric Summary Type: train_mae -- {'0_fold': 0.7752, '1_fold': 0.7253, '2_fold': 0.7025, '3_fold': 0.8178}
# Metric Summary Type: val_mae -- {'0_fold': 0.6259, '1_fold': 0.6162, '2_fold': 0.5891, '3_fold': 0.6097}
# Metric Summary Type: train_rmse -- {'0_fold': 1.0017, '1_fold': 0.9481, '2_fold': 0.8768, '3_fold': 1.1624}
# Metric Summary Type: val_rmse -- {'0_fold': 0.7347, '1_fold': 0.6938, '2_fold': 0.6978, '3_fold': 0.6901}
# _____________________________________
# Collection Type: min_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.1641, '1_fold': 0.1863, '2_fold': 0.153, '3_fold': 0.1521}
# Metric Summary Type: val_loss -- {'0_fold': 0.1657, '1_fold': 0.144, '2_fold': 0.1503, '3_fold': 0.1425}
# Metric Summary Type: train_r2 -- {'0_fold': -1.0816, '1_fold': -1.6366, '2_fold': -0.351, '3_fold': -0.8524}
# Metric Summary Type: val_r2 -- {'0_fold': -0.1609, '1_fold': -0.0166, '2_fold': 0.0275, '3_fold': -0.067}
# Metric Summary Type: train_mae -- {'0_fold': 0.3214, '1_fold': 0.3426, '2_fold': 0.3107, '3_fold': 0.3114}
# Metric Summary Type: val_mae -- {'0_fold': 0.3231, '1_fold': 0.2997, '2_fold': 0.2965, '3_fold': 0.294}
# Metric Summary Type: train_rmse -- {'0_fold': 0.4051, '1_fold': 0.4316, '2_fold': 0.3911, '3_fold': 0.3901}
# Metric Summary Type: val_rmse -- {'0_fold': 0.407, '1_fold': 0.3794, '2_fold': 0.3877, '3_fold': 0.3775}
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.1526, '1_fold': 0.1513, '2_fold': 0.1457, '3_fold': 0.1708}
# Metric Summary Type: val_loss -- {'0_fold': 0.1466, '1_fold': 0.1462, '2_fold': 0.1468, '3_fold': 0.1423}
# Metric Summary Type: train_r2 -- {'0_fold': -0.9923, '1_fold': -0.7924, '2_fold': -0.5254, '3_fold': -1.6799}
# Metric Summary Type: val_r2 -- {'0_fold': -0.0748, '1_fold': 0.054, '2_fold': 0.0291, '3_fold': 0.0483}
# Metric Summary Type: train_mae -- {'0_fold': 0.3075, '1_fold': 0.3064, '2_fold': 0.3021, '3_fold': 0.3291}
# Metric Summary Type: val_mae -- {'0_fold': 0.3016, '1_fold': 0.2945, '2_fold': 0.2909, '3_fold': 0.3066}
# Metric Summary Type: train_rmse -- {'0_fold': 0.3906, '1_fold': 0.389, '2_fold': 0.3817, '3_fold': 0.4133}
# Metric Summary Type: val_rmse -- {'0_fold': 0.3829, '1_fold': 0.3824, '2_fold': 0.3831, '3_fold': 0.3773}
# _____________________________________
# Collection Type: min_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 0.1521
# Metric Summary Type: val_loss -- 0.1425
# Metric Summary Type: train_r2 -- -1.6366
# Metric Summary Type: val_r2 -- -0.1609
# Metric Summary Type: train_mae -- 0.310699999332428
# Metric Summary Type: val_mae -- 0.2939999997615814
# Metric Summary Type: train_rmse -- 0.39010000228881836
# Metric Summary Type: val_rmse -- 0.3774999976158142
# _____________________________________
# Dataslice:  exclude_all_q_values_StandardScaler_embeddings
# Metric Summary Type: train_loss -- 0.1457
# Metric Summary Type: val_loss -- 0.1423
# Metric Summary Type: train_r2 -- -1.6799
# Metric Summary Type: val_r2 -- -0.0748
# Metric Summary Type: train_mae -- 0.3021000027656555
# Metric Summary Type: val_mae -- 0.29089999198913574
# Metric Summary Type: train_rmse -- 0.3817000091075897
# Metric Summary Type: val_rmse -- 0.3772999942302704
# _____________________________________

# %% [markdown]
# Experiment 5) Embedding Max Overfitting

# %%
performance_summary("model_results/ProteinCNN_Embedding_w_AA_w_Dropout_w_BatchNorm_model_Training_Slice_exclude_high_q_values_MinMax_embeddings.pkl")

# %% [markdown]
# Experiment 6) OneHot Encoding w AA w Dropout

# %%
performance_summary("./model_results/ProteinCNN_OneHot_w_AA_w_Dropout_model_Training_Slice_exclude_high_q_values_MinMax_one_hot.pkl")
# Out:
# Collection Type: avg_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_one_hot
# Metric Summary Type: train_loss -- {'0_fold': 0.3033, '1_fold': 0.3133}
# Metric Summary Type: val_loss -- {'0_fold': 0.2694, '1_fold': 0.2715}
# Metric Summary Type: train_r2 -- {'0_fold': 0.3947, '1_fold': 0.3803}
# Metric Summary Type: val_r2 -- {'0_fold': 0.4671, '1_fold': 0.4582}
# Metric Summary Type: train_mae -- {'0_fold': 0.4382, '1_fold': 0.4461}
# Metric Summary Type: val_mae -- {'0_fold': 0.419, '1_fold': 0.4241}
# Metric Summary Type: train_rmse -- {'0_fold': 0.5371, '1_fold': 0.5453}
# Metric Summary Type: val_rmse -- {'0_fold': 0.5107, '1_fold': 0.5141}
# _____________________________________
# Collection Type: avg_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_one_hot
# Metric Summary Type: train_loss -- 0.3083
# Metric Summary Type: val_loss -- 0.2704
# Metric Summary Type: train_r2 -- 0.3875
# Metric Summary Type: val_r2 -- 0.4626
# Metric Summary Type: train_mae -- 0.44209998846054077
# Metric Summary Type: val_mae -- 0.42149999737739563
# Metric Summary Type: train_rmse -- 0.5411999821662903
# Metric Summary Type: val_rmse -- 0.5123999714851379
# _____________________________________
# Collection Type: max_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_one_hot
# Metric Summary Type: train_loss -- 0.8525
# Metric Summary Type: val_loss -- 0.5005
# Metric Summary Type: train_r2 -- 0.662
# Metric Summary Type: val_r2 -- 0.6613
# Metric Summary Type: train_mae -- 0.7516999840736389
# Metric Summary Type: val_mae -- 0.6341999769210815
# Metric Summary Type: train_rmse -- 0.92330002784729
# Metric Summary Type: val_rmse -- 0.7074999809265137
# _____________________________________
# Collection Type: max_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_one_hot
# Metric Summary Type: train_loss -- {'0_fold': 0.7446, '1_fold': 0.8525}
# Metric Summary Type: val_loss -- {'0_fold': 0.5005, '1_fold': 0.4987}
# Metric Summary Type: train_r2 -- {'0_fold': 0.662, '1_fold': 0.6609}
# Metric Summary Type: val_r2 -- {'0_fold': 0.6613, '1_fold': 0.6553}
# Metric Summary Type: train_mae -- {'0_fold': 0.7137, '1_fold': 0.7517}
# Metric Summary Type: val_mae -- {'0_fold': 0.6284, '1_fold': 0.6342}
# Metric Summary Type: train_rmse -- {'0_fold': 0.8629, '1_fold': 0.9233}
# Metric Summary Type: val_rmse -- {'0_fold': 0.7075, '1_fold': 0.7062}
# _____________________________________
# Collection Type: min_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_one_hot
# Metric Summary Type: train_loss -- {'0_fold': 0.1693, '1_fold': 0.1715}
# Metric Summary Type: val_loss -- {'0_fold': 0.1712, '1_fold': 0.1727}
# Metric Summary Type: train_r2 -- {'0_fold': -0.4861, '1_fold': -0.6863}
# Metric Summary Type: val_r2 -- {'0_fold': 0.01, '1_fold': 0.0046}
# Metric Summary Type: train_mae -- {'0_fold': 0.3299, '1_fold': 0.3333}
# Metric Summary Type: val_mae -- {'0_fold': 0.3286, '1_fold': 0.3355}
# Metric Summary Type: train_rmse -- {'0_fold': 0.4115, '1_fold': 0.4141}
# Metric Summary Type: val_rmse -- {'0_fold': 0.4138, '1_fold': 0.4156}
# _____________________________________
# Collection Type: min_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_one_hot
# Metric Summary Type: train_loss -- 0.1693
# Metric Summary Type: val_loss -- 0.1712
# Metric Summary Type: train_r2 -- -0.6863
# Metric Summary Type: val_r2 -- 0.0046
# Metric Summary Type: train_mae -- 0.32989999651908875
# Metric Summary Type: val_mae -- 0.3285999894142151
# Metric Summary Type: train_rmse -- 0.4115000069141388
# Metric Summary Type: val_rmse -- 0.4138000011444092
# _____________________________________

# %% [markdown]
# ****
# ## RNN Experiments

# %% [markdown]
# Experiment 7) RNN_Embedding_w_AA_w_Dropout_Bidirectional

# %%
performance_summary("./model_results/ProteinRNN_Embedding_w_AA_w_Dropout_Bidirectional_model_Training_Slice_exclude_high_q_values_MinMax_embeddings.pkl")
# Out:
# Collection Type: avg_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.5333, '1_fold': 0.5332, '2_fold': 0.5514}
# Metric Summary Type: val_loss -- {'0_fold': 0.5033, '1_fold': 0.5096, '2_fold': 0.4962}
# Metric Summary Type: train_r2 -- {'0_fold': -0.0623, '1_fold': -0.0659, '2_fold': -0.0862}
# Metric Summary Type: val_r2 -- {'0_fold': 0.0051, '1_fold': -0.0004, '2_fold': -0.0032}
# Metric Summary Type: train_mae -- {'0_fold': 0.6345, '1_fold': 0.6333, '2_fold': 0.6412}
# Metric Summary Type: val_mae -- {'0_fold': 0.6216, '1_fold': 0.6304, '2_fold': 0.6201}
# Metric Summary Type: train_rmse -- {'0_fold': 0.7299, '1_fold': 0.7298, '2_fold': 0.7419}
# Metric Summary Type: val_rmse -- {'0_fold': 0.7094, '1_fold': 0.7138, '2_fold': 0.7044}
# _____________________________________
# Collection Type: avg_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 0.5393
# Metric Summary Type: val_loss -- 0.503
# Metric Summary Type: train_r2 -- -0.0715
# Metric Summary Type: val_r2 -- 0.0005
# Metric Summary Type: train_mae -- 0.6363000273704529
# Metric Summary Type: val_mae -- 0.6241000294685364
# Metric Summary Type: train_rmse -- 0.7339000105857849
# Metric Summary Type: val_rmse -- 0.7092000246047974
# _____________________________________
# Collection Type: max_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 0.7081
# Metric Summary Type: val_loss -- 0.5397
# Metric Summary Type: train_r2 -- -0.0169
# Metric Summary Type: val_r2 -- 0.0364
# Metric Summary Type: train_mae -- 0.7016000151634216
# Metric Summary Type: val_mae -- 0.6521999835968018
# Metric Summary Type: train_rmse -- 0.8414999842643738
# Metric Summary Type: val_rmse -- 0.7347000241279602
# _____________________________________
# Collection Type: max_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.636, '1_fold': 0.6476, '2_fold': 0.7081}
# Metric Summary Type: val_loss -- {'0_fold': 0.5308, '1_fold': 0.5397, '2_fold': 0.5236}
# Metric Summary Type: train_r2 -- {'0_fold': -0.0169, '1_fold': -0.021, '2_fold': -0.0299}
# Metric Summary Type: val_r2 -- {'0_fold': 0.028, '1_fold': 0.0364, '2_fold': 0.0231}
# Metric Summary Type: train_mae -- {'0_fold': 0.6751, '1_fold': 0.6791, '2_fold': 0.7016}
# Metric Summary Type: val_mae -- {'0_fold': 0.6522, '1_fold': 0.6473, '2_fold': 0.6442}
# Metric Summary Type: train_rmse -- {'0_fold': 0.7975, '1_fold': 0.8047, '2_fold': 0.8415}
# Metric Summary Type: val_rmse -- {'0_fold': 0.7286, '1_fold': 0.7347, '2_fold': 0.7236}
# _____________________________________
# Collection Type: min_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.5105, '1_fold': 0.5108, '2_fold': 0.5228}
# Metric Summary Type: val_loss -- {'0_fold': 0.4917, '1_fold': 0.4909, '2_fold': 0.4832}
# Metric Summary Type: train_r2 -- {'0_fold': -0.2669, '1_fold': -0.2943, '2_fold': -0.3948}
# Metric Summary Type: val_r2 -- {'0_fold': -0.0493, '1_fold': -0.0596, '2_fold': -0.0586}
# Metric Summary Type: train_mae -- {'0_fold': 0.6226, '1_fold': 0.6225, '2_fold': 0.6292}
# Metric Summary Type: val_mae -- {'0_fold': 0.5982, '1_fold': 0.6112, '2_fold': 0.6057}
# Metric Summary Type: train_rmse -- {'0_fold': 0.7145, '1_fold': 0.7147, '2_fold': 0.723}
# Metric Summary Type: val_rmse -- {'0_fold': 0.7012, '1_fold': 0.7006, '2_fold': 0.6951}
# _____________________________________
# Collection Type: min_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 0.5105
# Metric Summary Type: val_loss -- 0.4832
# Metric Summary Type: train_r2 -- -0.3948
# Metric Summary Type: val_r2 -- -0.0596
# Metric Summary Type: train_mae -- 0.6225000023841858
# Metric Summary Type: val_mae -- 0.5982000231742859
# Metric Summary Type: train_rmse -- 0.7145000100135803
# Metric Summary Type: val_rmse -- 0.6951000094413757
# _____________________________________

# %% [markdown]
# Experiment 8) Embedding_w_AA_w_DropOut_No_Bidirectional

# %%
performance_summary("./model_results/ProteinRNN_Embedding_w_AA_w_Dropout_model_Training_Slice_exclude_high_q_values_MinMax_embeddings.pkl")
# Out:
# Collection Type: avg_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.5319, '1_fold': 0.5359, '2_fold': 0.5391}
# Metric Summary Type: val_loss -- {'0_fold': 0.5022, '1_fold': 0.5031, '2_fold': 0.4939}
# Metric Summary Type: train_r2 -- {'0_fold': -0.0594, '1_fold': -0.0712, '2_fold': -0.062}
# Metric Summary Type: val_r2 -- {'0_fold': 0.0074, '1_fold': 0.0123, '2_fold': 0.0015}
# Metric Summary Type: train_mae -- {'0_fold': 0.6343, '1_fold': 0.6338, '2_fold': 0.6353}
# Metric Summary Type: val_mae -- {'0_fold': 0.6198, '1_fold': 0.6311, '2_fold': 0.6202}
# Metric Summary Type: train_rmse -- {'0_fold': 0.7286, '1_fold': 0.7314, '2_fold': 0.7335}
# Metric Summary Type: val_rmse -- {'0_fold': 0.7086, '1_fold': 0.7093, '2_fold': 0.7027}
# _____________________________________
# Collection Type: avg_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 0.5356
# Metric Summary Type: val_loss -- 0.4997
# Metric Summary Type: train_r2 -- -0.0642
# Metric Summary Type: val_r2 -- 0.0071
# Metric Summary Type: train_mae -- 0.6345000267028809
# Metric Summary Type: val_mae -- 0.6237000226974487
# Metric Summary Type: train_rmse -- 0.7311999797821045
# Metric Summary Type: val_rmse -- 0.7067999839782715
# _____________________________________
# Collection Type: max_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 0.7014
# Metric Summary Type: val_loss -- 0.542
# Metric Summary Type: train_r2 -- 0.0044
# Metric Summary Type: val_r2 -- 0.0432
# Metric Summary Type: train_mae -- 0.6978999972343445
# Metric Summary Type: val_mae -- 0.6571999788284302
# Metric Summary Type: train_rmse -- 0.8374999761581421
# Metric Summary Type: val_rmse -- 0.7361999750137329
# _____________________________________
# Collection Type: max_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.684, '1_fold': 0.6854, '2_fold': 0.7014}
# Metric Summary Type: val_loss -- {'0_fold': 0.5306, '1_fold': 0.5264, '2_fold': 0.542}
# Metric Summary Type: train_r2 -- {'0_fold': 0.0044, '1_fold': -0.0143, '2_fold': -0.0051}
# Metric Summary Type: val_r2 -- {'0_fold': 0.0432, '1_fold': 0.0382, '2_fold': 0.031}
# Metric Summary Type: train_mae -- {'0_fold': 0.6962, '1_fold': 0.6924, '2_fold': 0.6979}
# Metric Summary Type: val_mae -- {'0_fold': 0.6417, '1_fold': 0.6523, '2_fold': 0.6572}
# Metric Summary Type: train_rmse -- {'0_fold': 0.8271, '1_fold': 0.8279, '2_fold': 0.8375}
# Metric Summary Type: val_rmse -- {'0_fold': 0.7284, '1_fold': 0.7255, '2_fold': 0.7362}
# _____________________________________
# Collection Type: min_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.4998, '1_fold': 0.5075, '2_fold': 0.5102}
# Metric Summary Type: val_loss -- {'0_fold': 0.484, '1_fold': 0.4899, '2_fold': 0.4793}
# Metric Summary Type: train_r2 -- {'0_fold': -0.3625, '1_fold': -0.3699, '2_fold': -0.3818}
# Metric Summary Type: val_r2 -- {'0_fold': -0.0488, '1_fold': -0.0333, '2_fold': -0.0958}
# Metric Summary Type: train_mae -- {'0_fold': 0.6178, '1_fold': 0.6203, '2_fold': 0.6206}
# Metric Summary Type: val_mae -- {'0_fold': 0.5973, '1_fold': 0.6135, '2_fold': 0.6015}
# Metric Summary Type: train_rmse -- {'0_fold': 0.707, '1_fold': 0.7124, '2_fold': 0.7143}
# Metric Summary Type: val_rmse -- {'0_fold': 0.6957, '1_fold': 0.7, '2_fold': 0.6923}
# _____________________________________
# Collection Type: min_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 0.4998
# Metric Summary Type: val_loss -- 0.4793
# Metric Summary Type: train_r2 -- -0.3818
# Metric Summary Type: val_r2 -- -0.0958
# Metric Summary Type: train_mae -- 0.6177999973297119
# Metric Summary Type: val_mae -- 0.5972999930381775
# Metric Summary Type: train_rmse -- 0.7070000171661377
# Metric Summary Type: val_rmse -- 0.692300021648407
# _____________________________________

# %% [markdown]
# Experiment 9) GRU Architecture_w_AA_w_DropOut

# %%
performance_summary("./model_results/ProteinRNN_GRU_Embedding_w_AA_w_Dropout_Bidirectional_model_Training_Slice_exclude_high_q_values_MinMax_embeddings.pkl")
# Out:
# Collection Type: avg_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.5408, '1_fold': 0.5372, '2_fold': 0.5438}
# Metric Summary Type: val_loss -- {'0_fold': 0.5032, '1_fold': 0.5058, '2_fold': 0.4945}
# Metric Summary Type: train_r2 -- {'0_fold': -0.0772, '1_fold': -0.0737, '2_fold': -0.0713}
# Metric Summary Type: val_r2 -- {'0_fold': 0.0053, '1_fold': 0.0071, '2_fold': 0.0003}
# Metric Summary Type: train_mae -- {'0_fold': 0.6383, '1_fold': 0.6343, '2_fold': 0.6373}
# Metric Summary Type: val_mae -- {'0_fold': 0.6193, '1_fold': 0.628, '2_fold': 0.617}
# Metric Summary Type: train_rmse -- {'0_fold': 0.7346, '1_fold': 0.7322, '2_fold': 0.7366}
# Metric Summary Type: val_rmse -- {'0_fold': 0.7093, '1_fold': 0.7111, '2_fold': 0.7031}
# _____________________________________
# Collection Type: avg_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 0.5406
# Metric Summary Type: val_loss -- 0.5012
# Metric Summary Type: train_r2 -- -0.0741
# Metric Summary Type: val_r2 -- 0.0042
# Metric Summary Type: train_mae -- 0.6366000175476074
# Metric Summary Type: val_mae -- 0.621399998664856
# Metric Summary Type: train_rmse -- 0.734499990940094
# Metric Summary Type: val_rmse -- 0.7078999876976013
# _____________________________________
# Collection Type: max_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 0.7117
# Metric Summary Type: val_loss -- 0.5302
# Metric Summary Type: train_r2 -- -0.0007
# Metric Summary Type: val_r2 -- 0.0379
# Metric Summary Type: train_mae -- 0.7009999752044678
# Metric Summary Type: val_mae -- 0.6528000235557556
# Metric Summary Type: train_rmse -- 0.8435999751091003
# Metric Summary Type: val_rmse -- 0.7282000184059143
# _____________________________________
# Collection Type: max_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.7047, '1_fold': 0.6913, '2_fold': 0.7117}
# Metric Summary Type: val_loss -- {'0_fold': 0.5302, '1_fold': 0.5271, '2_fold': 0.5296}
# Metric Summary Type: train_r2 -- {'0_fold': -0.0245, '1_fold': -0.0172, '2_fold': -0.0007}
# Metric Summary Type: val_r2 -- {'0_fold': 0.0312, '1_fold': 0.0379, '2_fold': 0.0362}
# Metric Summary Type: train_mae -- {'0_fold': 0.701, '1_fold': 0.6934, '2_fold': 0.6995}
# Metric Summary Type: val_mae -- {'0_fold': 0.6523, '1_fold': 0.6528, '2_fold': 0.6388}
# Metric Summary Type: train_rmse -- {'0_fold': 0.8394, '1_fold': 0.8315, '2_fold': 0.8436}
# Metric Summary Type: val_rmse -- {'0_fold': 0.7282, '1_fold': 0.726, '2_fold': 0.7277}
# _____________________________________
# Collection Type: min_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.5143, '1_fold': 0.5089, '2_fold': 0.508}
# Metric Summary Type: val_loss -- {'0_fold': 0.4901, '1_fold': 0.4901, '2_fold': 0.4767}
# Metric Summary Type: train_r2 -- {'0_fold': -0.4036, '1_fold': -0.3819, '2_fold': -0.402}
# Metric Summary Type: val_r2 -- {'0_fold': -0.0482, '1_fold': -0.0347, '2_fold': -0.0707}
# Metric Summary Type: train_mae -- {'0_fold': 0.6257, '1_fold': 0.6207, '2_fold': 0.6196}
# Metric Summary Type: val_mae -- {'0_fold': 0.6027, '1_fold': 0.6079, '2_fold': 0.6048}
# Metric Summary Type: train_rmse -- {'0_fold': 0.7172, '1_fold': 0.7134, '2_fold': 0.7127}
# Metric Summary Type: val_rmse -- {'0_fold': 0.7001, '1_fold': 0.7001, '2_fold': 0.6905}
# _____________________________________
# Collection Type: min_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 0.508
# Metric Summary Type: val_loss -- 0.4767
# Metric Summary Type: train_r2 -- -0.4036
# Metric Summary Type: val_r2 -- -0.0707
# Metric Summary Type: train_mae -- 0.6195999979972839
# Metric Summary Type: val_mae -- 0.6026999950408936
# Metric Summary Type: train_rmse -- 0.7127000093460083
# Metric Summary Type: val_rmse -- 0.690500020980835
# _____________________________________

# %% [markdown]
# Experiment 10) Padding Re-training

# %%
performance_summary("./model_results/ProteinCNN_Embedding_w_AA_w_Dropout_w_PADDING_model_Training_Slice_exclude_high_q_values_MinMax_embeddings.pkl")
# Out:
# Collection Type: avg_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.2568, '1_fold': 0.2682, '2_fold': 0.2432, '3_fold': 0.2475}
# Metric Summary Type: val_loss -- {'0_fold': 0.2321, '1_fold': 0.2505, '2_fold': 0.2338, '3_fold': 0.2306}
# Metric Summary Type: train_r2 -- {'0_fold': 0.4902, '1_fold': 0.4652, '2_fold': 0.5174, '3_fold': 0.5092}
# Metric Summary Type: val_r2 -- {'0_fold': 0.5379, '1_fold': 0.5077, '2_fold': 0.5338, '3_fold': 0.5393}
# Metric Summary Type: train_mae -- {'0_fold': 0.3956, '1_fold': 0.4092, '2_fold': 0.3879, '3_fold': 0.3935}
# Metric Summary Type: val_mae -- {'0_fold': 0.3847, '1_fold': 0.3954, '2_fold': 0.3828, '3_fold': 0.384}
# Metric Summary Type: train_rmse -- {'0_fold': 0.4896, '1_fold': 0.5045, '2_fold': 0.4794, '3_fold': 0.4863}
# Metric Summary Type: val_rmse -- {'0_fold': 0.4734, '1_fold': 0.4888, '2_fold': 0.4745, '3_fold': 0.4718}
# _____________________________________
# Collection Type: avg_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 0.2539
# Metric Summary Type: val_loss -- 0.2367
# Metric Summary Type: train_r2 -- 0.4955
# Metric Summary Type: val_r2 -- 0.5297
# Metric Summary Type: train_mae -- 0.39649999141693115
# Metric Summary Type: val_mae -- 0.38670000433921814
# Metric Summary Type: train_rmse -- 0.48989999294281006
# Metric Summary Type: val_rmse -- 0.4771000146865845
# _____________________________________
# Collection Type: max_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 0.869
# Metric Summary Type: val_loss -- 0.5345
# Metric Summary Type: train_r2 -- 0.7412
# Metric Summary Type: val_r2 -- 0.7336
# Metric Summary Type: train_mae -- 0.7365000247955322
# Metric Summary Type: val_mae -- 0.6251000165939331
# Metric Summary Type: train_rmse -- 0.932200014591217
# Metric Summary Type: val_rmse -- 0.7311000227928162
# _____________________________________
# Collection Type: max_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.869, '1_fold': 0.774, '2_fold': 0.6912, '3_fold': 0.6111}
# Metric Summary Type: val_loss -- {'0_fold': 0.5103, '1_fold': 0.5345, '2_fold': 0.4868, '3_fold': 0.4704}
# Metric Summary Type: train_r2 -- {'0_fold': 0.7412, '1_fold': 0.6923, '2_fold': 0.7366, '3_fold': 0.7069}
# Metric Summary Type: val_r2 -- {'0_fold': 0.725, '1_fold': 0.7336, '2_fold': 0.717, '3_fold': 0.7226}
# Metric Summary Type: train_mae -- {'0_fold': 0.7365, '1_fold': 0.7152, '2_fold': 0.6923, '3_fold': 0.6615}
# Metric Summary Type: val_mae -- {'0_fold': 0.6005, '1_fold': 0.6072, '2_fold': 0.6251, '3_fold': 0.612}
# Metric Summary Type: train_rmse -- {'0_fold': 0.9322, '1_fold': 0.8798, '2_fold': 0.8314, '3_fold': 0.7818}
# Metric Summary Type: val_rmse -- {'0_fold': 0.7143, '1_fold': 0.7311, '2_fold': 0.6977, '3_fold': 0.6858}
# _____________________________________
# Collection Type: min_score_per_fold
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- {'0_fold': 0.1303, '1_fold': 0.1543, '2_fold': 0.1327, '3_fold': 0.1478}
# Metric Summary Type: val_loss -- {'0_fold': 0.1381, '1_fold': 0.1356, '2_fold': 0.1419, '3_fold': 0.1388}
# Metric Summary Type: train_r2 -- {'0_fold': -0.7254, '1_fold': -0.5434, '2_fold': -0.3715, '3_fold': -0.2121}
# Metric Summary Type: val_r2 -- {'0_fold': -0.0159, '1_fold': -0.0504, '2_fold': 0.0293, '3_fold': 0.0602}
# Metric Summary Type: train_mae -- {'0_fold': 0.2853, '1_fold': 0.3092, '2_fold': 0.2876, '3_fold': 0.3046}
# Metric Summary Type: val_mae -- {'0_fold': 0.288, '1_fold': 0.2851, '2_fold': 0.2871, '3_fold': 0.2922}
# Metric Summary Type: train_rmse -- {'0_fold': 0.361, '1_fold': 0.3928, '2_fold': 0.3643, '3_fold': 0.3844}
# Metric Summary Type: val_rmse -- {'0_fold': 0.3717, '1_fold': 0.3682, '2_fold': 0.3767, '3_fold': 0.3726}
# _____________________________________
# Collection Type: min_score_per_metric
# Dataslice:  exclude_high_q_values_MinMax_embeddings
# Metric Summary Type: train_loss -- 0.1303
# Metric Summary Type: val_loss -- 0.1356
# Metric Summary Type: train_r2 -- -0.7254
# Metric Summary Type: val_r2 -- -0.0504
# Metric Summary Type: train_mae -- 0.28529998660087585
# Metric Summary Type: val_mae -- 0.2851000130176544
# Metric Summary Type: train_rmse -- 0.3610000014305115
# Metric Summary Type: val_rmse -- 0.36820000410079956
# _____________________________________
